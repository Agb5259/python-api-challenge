# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
weather_api_key
# Out:
# '0278982b87048deb73a3ffafa337c8e3'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %%
cities
# Out:
# ['waitangi',
#  'kudahuvadhoo',
#  'auki',
#  'thompson',
#  'invercargill',
#  'isafjordur',
#  'ulsteinvik',
#  'west island',
#  'san patricio',
#  'adamstown',
#  'grytviken',
#  'ryotsu-minato',
#  'tolanaro',
#  'hamilton',
#  'barnard castle',
#  'bengkulu',
#  'tiksi',
#  'tadine',
#  'copiapo',
#  'edinburgh of the seven seas',
#  'port-aux-francais',
#  'poronaysk',
#  'naze',
#  'bredasdorp',
#  'tovarkovo',
#  'crane',
#  'remontnoye',
#  'hasaki',
#  'colonia',
#  'callao',
#  'klyuchi',
#  'puerto ayora',
#  'bikenibeu village',
#  'sosua',
#  'taiohae',
#  'midvagur',
#  'utrik',
#  'coracora',
#  'tomatlan',
#  'novodvinsk',
#  'hawaiian paradise park',
#  'albany',
#  'iqaluit',
#  'bethel',
#  'marco island',
#  'san antonio del estrecho',
#  'blackmans bay',
#  'bhimunipatnam',
#  'vorgashor',
#  'melfi',
#  'kataba',
#  'rongelap',
#  'jhajjar',
#  'suntar',
#  'howard springs',
#  'bilibino',
#  'tongchuanshi',
#  'haapsalu',
#  'midelt',
#  'whitehorse',
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_name_without_spaces = city.replace(" ", "%20")
    city_url = f"{url}q={city_name_without_spaces}&appid={weather_api_key}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

     # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | kudahuvadhoo
# Processing Record 3 of Set 1 | auki
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | invercargill
# Processing Record 6 of Set 1 | isafjordur
# Processing Record 7 of Set 1 | ulsteinvik
# Processing Record 8 of Set 1 | west island
# Processing Record 9 of Set 1 | san patricio
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | grytviken
# Processing Record 12 of Set 1 | ryotsu-minato
# Processing Record 13 of Set 1 | tolanaro
# Processing Record 14 of Set 1 | hamilton
# Processing Record 15 of Set 1 | barnard castle
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | tadine
# Processing Record 19 of Set 1 | copiapo
# Processing Record 20 of Set 1 | edinburgh of the seven seas
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          575
# Lat           575
# Lng           575
# Max Temp      575
# Humidity      575
# Cloudiness    575
# Wind Speed    575
# Country       575
# Date          575
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      waitangi -43.9535 -176.5597    283.61        85          79
# 1  kudahuvadhoo   2.6708   72.8944    302.53        76          59
# 2          auki  -8.7676  160.7034    300.36        88         100
# 3      thompson  55.7435  -97.8558    283.24        93          75
# 4  invercargill -46.4000  168.3500    282.60        79         100
#
#    Wind Speed Country        Date
# 0        1.79      NZ  1715308316
# 1        5.02      MV  1715308361
# 2        1.42      SB  1715308362
# 3        2.06      CA  1715308282
# 4        4.47      NZ  1715308328

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Convert temp from Kelvin to Celsius
city_data_df['Max Temp'] = city_data_df['Max Temp'] - 273.15
city_data_df.rename(columns={'Max Temp': 'Max Temp Celsius'}, inplace=True)

# Convert Unix timestamps to year-month-day format
city_data_df['Date'] = pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d')

city_data_df.rename(columns={'Date': 'Formatted Date'}, inplace=True)

city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp Celsius  Humidity  \
# City_ID
# 0            waitangi -43.9535 -176.5597             10.46        85
# 1        kudahuvadhoo   2.6708   72.8944             29.38        76
# 2                auki  -8.7676  160.7034             27.21        88
# 3            thompson  55.7435  -97.8558             10.09        93
# 4        invercargill -46.4000  168.3500              9.45        79
#
#          Cloudiness  Wind Speed Country Formatted Date
# City_ID
# 0                79        1.79      NZ     2024-05-10
# 1                59        5.02      MV     2024-05-10
# 2               100        1.42      SB     2024-05-10
# 3                75        2.06      CA     2024-05-10
# 4               100        4.47      NZ     2024-05-10

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp Celsius'], marker='o', color='lightblue',edgecolors='black')

# Incorporate the other graph properties
plt.title(f'City Latitude vs Max Temperature ({city_data_df["Formatted Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', color='lightblue',edgecolors='black')

# Incorporate the other graph properties
plt.title(f'City Latitude vs Humidity ({city_data_df["Formatted Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', color='lightblue',edgecolors='black')

# Incorporate the other graph properties
plt.title(f'City Latitude vs Cloudiness ({city_data_df["Formatted Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker='o', color='lightblue',edgecolors='black')

# Incorporate the other graph properties
plt.title(f'City Latitude vs Wind Speed ({city_data_df["Formatted Date"].iloc[0]})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Function for linear regression plot
def create_linear_regression_plot(x, y, xlabel, ylabel):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)

    # Create scatter plot
    plt.scatter(x, y, color='blue', label='Data Points')

    # Add linear regression line to the plot
    plt.plot(x, intercept + slope * x, color='red', label='Linear Regression Line')

    # Add linear regression equation and r-value to the plot
    equation = f'Y = {slope:.2f}X + {intercept:.2f}'
    r_value_text = f'r = {r_value:.2f}'
    plt.text(0.05, 0.9, equation, transform=plt.gca().transAxes, fontsize=12)
    plt.text(0.05, 0.8, r_value_text, transform=plt.gca().transAxes, fontsize=12)

    # Add labels and legend
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()

    # Show plot
    plt.grid(True)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df =city_data_df[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat      Lng  Max Temp Celsius  Humidity  \
# City_ID
# 1        kudahuvadhoo   2.6708  72.8944             29.38        76
# 3            thompson  55.7435 -97.8558             10.09        93
# 5          isafjordur  66.0755 -23.1240              1.71        83
# 6          ulsteinvik  62.3432   5.8487              5.97        83
# 8        san patricio  28.0170 -97.5169             28.24        82
#
#          Cloudiness  Wind Speed Country Formatted Date
# City_ID
# 1                59        5.02      MV     2024-05-10
# 3                75        2.06      CA     2024-05-10
# 5                98        1.23      IS     2024-05-10
# 6                88        1.79      NO     2024-05-10
# 8                 0        4.31      US     2024-05-10

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp Celsius  Humidity  \
# City_ID
# 0            waitangi -43.9535 -176.5597             10.46        85
# 2                auki  -8.7676  160.7034             27.21        88
# 4        invercargill -46.4000  168.3500              9.45        79
# 7         west island -12.1568   96.8225             27.99        69
# 9           adamstown -25.0660 -130.1015             22.38        78
#
#          Cloudiness  Wind Speed Country Formatted Date
# City_ID
# 0                79        1.79      NZ     2024-05-10
# 2               100        1.42      SB     2024-05-10
# 4               100        4.47      NZ     2024-05-10
# 7               100        8.75      CC     2024-05-10
# 9                86        4.66      PN     2024-05-10

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
create_linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Max Temp Celsius"], "Lat", "Max Temp Celsius")

# %%
# Linear regression on Southern Hemisphere
create_linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Max Temp Celsius"], "Lat", "Max Temp Celsius")

# %% [markdown]
# **Discussion about the linear relationship:**There is a positive linear relationship between latitudes in the southern hemisphere and max temperature. So as we get closer to the equater, max temp increases which is expected. The linear regression model is a good fit to the data.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Lat", "Humidity")

# %%
# Southern Hemisphere
create_linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Lat", "Humidity")

# %% [markdown]
# **Discussion about the linear relationship:** There is a positive linear relationship between latitudes in the southern hemisphere and Humidity. So as we get closer to the equater, humidity increases. The relationship is not strong or very conclusive. The linear regression model does not do a great job of explaining the relationship between the two variables, hence the linear regression model is not a good fit.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Lat", "Cloudiness")

# %%
# Southern Hemisphere
create_linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Lat", "Cloudiness")

# %% [markdown]
# **Discussion about the linear relationship:** There is a positive linear relationship between latitudes in the southern hemisphere and Cloudiness. So as we get closer to the equater, cloudiness increases. The relationship is not strong or very conclusive. The linear regression model does not do a great job of explaining the relationship between the two variables, hence the linear regression model is not a good fit.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Lat", "Wind Speed")

# %%
# Southern Hemisphere
create_linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Lat", "Wind Speed")

# %% [markdown]
# **Discussion about the linear relationship:** There is a negative linear relationship between latitudes in the southern hemisphere and Wind Speed. So as we get closer to the equater, wind speed dec. The linear regression model is a good fit to the data.
