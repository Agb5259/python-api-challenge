# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b054cfa0-ac40-48c8-b2a6-f2e485554761" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"2eaf5b31-46cb-4024-8156-bf3e2f9f534d":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"51d558bb9c8a45a4a2cdaa3b0359a831","client_comm_id":"6b5dc93e8a6347d7bc658b0aee8b8207"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"2eaf5b31-46cb-4024-8156-bf3e2f9f534d","roots":{"p1002":"b054cfa0-ac40-48c8-b2a6-f2e485554761"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")
# Convert temp from Kelvin to Celsuis
city_data_df['Max Temp'] = city_data_df['Max Temp'] - 273.15
city_data_df.rename(columns={'Max Temp': 'Max Temp Celsius'}, inplace=True)
# Convert from unix time stampe to year-month-day format
city_data_df['Date'] = pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d')
city_data_df.rename(columns={'Date': 'Formatted Date'}, inplace=True)
# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp Celsius  Humidity  \
# 0        0     okakarara -20.5833   17.4333             19.01        35
# 1        1     adamstown -25.0660 -130.1015             21.79        78
# 2        2         lihue  21.9789 -159.3672             26.58        69
# 3        3      sai buri   6.7013  101.6168             27.76        79
# 4        4  punta arenas -53.1500  -70.9167              3.06        87
#
#    Cloudiness  Wind Speed Country Formatted Date
# 0           4        2.52     NaN     2024-05-07
# 1          59        4.09      PN     2024-05-07
# 2          20        6.17      US     2024-05-07
# 3          80        1.50      TH     2024-05-07
# 4         100        5.14      CL     2024-05-07

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    'Lng', 'Lat', geo=True, tiles='OSM', size='Humidity', 
    hover_cols=['City', 'Humidity'], title='Map Plot Example',
    frame_width=600, frame_height=400  # Adjust frame size if needed
)
# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
filtered_city_data_df =  city_data_df[(city_data_df['Max Temp Celsius']<27) & (city_data_df['Max Temp Celsius']>21) & (city_data_df['Wind Speed']<4.5) & (city_data_df['Cloudiness']==0)]

# Drop any rows with null values
filtered_city_data_df.dropna()

# Display sample data
filtered_city_data_df
# Out:
#      City_ID              City      Lat       Lng  Max Temp Celsius  Humidity  \
# 56        56          karratha -20.7377  116.8463             24.25        69
# 81        81            bethel  41.3712  -73.4140             26.70        28
# 109      109             sajir  25.1825   44.5996             26.50        11
# 176      176           toliara -23.3500   43.6667             22.20        65
# 184      184  katsuren-haebaru  26.3369  127.8719             22.01        89
# 209      209             tabas  33.5959   56.9244             26.12        31
# 299      299         jamestown  42.0970  -79.2353             25.29        44
# 302      302          penn yan  42.6609  -77.0539             23.98        24
# 308      308         inhambane -23.8650   35.3833             22.59        74
# 338      338         guarapari -20.6667  -40.4975             24.69        88
# 371      371       al kharijah  25.4514   30.5464             22.49        23
# 391      391           eastham  41.8301  -69.9739             21.18        63
# 485      485      antonio enes -16.2325   39.9086             25.38        76
# 487      487           itacare -14.2775  -38.9967             26.07        79
# 493      493             prado -17.3411  -39.2208             25.29        86
# 524      524           bilbays  30.4204   31.5622             21.46        61
#
#      Cloudiness  Wind Speed Country Formatted Date
# 56            0        1.78      AU     2024-05-07
# 81            0        3.60      US     2024-05-07
# 109           0        3.13      SA     2024-05-07
# 176           0        3.91      MG     2024-05-07
# 184           0        2.06      JP     2024-05-07
# 209           0        3.09      IR     2024-05-07
# 299           0        1.79      US     2024-05-07
# 302           0        3.13      US     2024-05-07
# 308           0        3.23      MZ     2024-05-07
# 338           0        3.73      BR     2024-05-07
# 371           0        3.99      EG     2024-05-07
# 391           0        2.06      US     2024-05-07
# 485           0        2.99      MZ     2024-05-07
# 487           0        3.63      BR     2024-05-07
# 493           0        2.59      BR     2024-05-07
# 524           0        2.80      EG     2024-05-07

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel name"] = ""

# Display sample data
hotel_df
# Out:
#              City Country      Lat       Lng  Humidity Hotel name
# 0       okakarara     NaN -20.5833   17.4333        35
# 1       adamstown      PN -25.0660 -130.1015        78
# 2           lihue      US  21.9789 -159.3672        69
# 3        sai buri      TH   6.7013  101.6168        79
# 4    punta arenas      CL -53.1500  -70.9167        87
# ..            ...     ...      ...       ...       ...        ...
# 574      egersund      NO  58.4513    5.9997        87
# 575      tomatlan      MX  19.9333 -105.2500        35
# 576       kewanee      US  41.2456  -89.9248        54
# 577  faya-largeau      TD  17.9257   19.1043        13
# 578       itabera      BR -23.8619  -49.1372        50
#
# [579 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Helped by tutor for this whole section
radius = 10_000  # Adjusted for proper integer representation

# Set parameters to search for a hotel
params = {
    "categories": 'accommodation.hotel',
    "filter": '',
    "limit": 20,
    "apiKey": geoapify_key  
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lng = row["Lng"]
    lat = row["Lat"]

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lng},{lat},{radius}'
    params["bias"] = f'proximity:{lng},{lat}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Convert the API response to JSON format
        data = response.json()
        
        # Grab the first hotel from the results and store the name in the hotel_df DataFrame
        try:
            hotel_name = data["features"][0]["properties"]["name"]
            hotel_df.loc[index, "Hotel name"] = hotel_name
        except (KeyError, IndexError):
            # If no hotel is found, set the hotel name as "No hotel found".
            hotel_df.loc[index, "Hotel name"] = "No hotel found"
    else:
        print(f"Failed to retrieve hotels for {row['City']}. Status code: {response.status_code}")

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel name']}")

# Display sample data
print(hotel_df)
# Out:
# Starting hotel search
# okakarara - nearest hotel: No hotel found
# adamstown - nearest hotel: No hotel found
# lihue - nearest hotel: Kauai Palms
# sai buri - nearest hotel: موقع .٢ مشروع فندق
# punta arenas - nearest hotel: Hotel Lacolet
# east london - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# edinburgh of the seven seas - nearest hotel: No hotel found
# piti village - nearest hotel: The Cliff Hotel
# grytviken - nearest hotel: No hotel found
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# walker - nearest hotel: La Quinta Inn
# isafjordur - nearest hotel: Hótel Horn
# waitangi - nearest hotel: Hotel Chathams
# iqaluit - nearest hotel: Frobisher Inn
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# georgetown - nearest hotel: Page 63 hostel
# burgas - nearest hotel: Космос
# ust-nera - nearest hotel: гостиница "Солнечная"
# nantucket - nearest hotel: No hotel found
# blackmans bay - nearest hotel: Villa Howden
# ancud - nearest hotel: Cabañas
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# constantia - nearest hotel: Hotel Chérica
# katabu - nearest hotel: No hotel found
# kruisfontein - nearest hotel: No hotel found
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# modimolle - nearest hotel: Mezi Mezi Guest House
# port-aux-francais - nearest hotel: Keravel
# thompson - nearest hotel: Thompson Inn
# dudinka - nearest hotel: Виктория
# lobujya - nearest hotel: Himalaya Lodge
# necochea - nearest hotel: Cabañas Río Quequén
# puerto natales - nearest hotel: Dorotea Patagonia Hostel
# kayangel - nearest hotel: No hotel found
# itoman - nearest hotel: No hotel found
# papatowai - nearest hotel: No hotel found
# hamilton - nearest hotel: North Vista Manor
# suomussalmi - nearest hotel: Kiannon kuohut
# ongjin - nearest hotel: No hotel found
# visalia - nearest hotel: Comfort Suites
# muravlenko - nearest hotel: Е-Отель
# nizhnyaya salda - nearest hotel: No hotel found
# kill devil hills - nearest hotel: Mariner Days Inn & Suites
# buka - nearest hotel: No hotel found
# port alfred - nearest hotel: No hotel found
# alice springs - nearest hotel: Aurora Alice Springs
# yellowknife - nearest hotel: No hotel found
# mournies - nearest hotel: Oasis
# hadibu - nearest hotel: No hotel found
# ambatofinandrahana - nearest hotel: No hotel found
# tamanrasset - nearest hotel: فندق الأمان
# sanctuary point - nearest hotel: Dungowan Accommodation
# kotlas - nearest hotel: Советская
# karratha - nearest hotel: Karratha International Hotel
# ketchikan - nearest hotel: Cape Fox Lodge
# olonkinbyen - nearest hotel: No hotel found
# shingu - nearest hotel: ホテルニューパレス
# sungjibaegam - nearest hotel: No hotel found
# newnham - nearest hotel: Riverside Hotel Motel
# las vegas - nearest hotel: Downtown Grand
# yuxia - nearest hotel: No hotel found
# sing buri - nearest hotel: Mabuna Resort
# uturoa - nearest hotel: Hawaiki Nui hotel
# tete - nearest hotel: Zambezi Hotel
# muroto-misakicho - nearest hotel: 民宿うらしま
# partizansk - nearest hotel: сучан
# mejit - nearest hotel: No hotel found
# lamu - nearest hotel: Hotel Archipelago villa bed and breakfast
# avarua - nearest hotel: Paradise Inn
# fale old settlement - nearest hotel: No hotel found
# san luis de la loma - nearest hotel: No hotel found
# tiksi - nearest hotel: Арктика
# puerto santa - nearest hotel: No hotel found
# tadine - nearest hotel: Hôtel Nengoné
# panama city beach - nearest hotel: Shores of Panama
# manokwari - nearest hotel: Hotel Arfak
# alofi - nearest hotel: Matavai Resort
# hithadhoo - nearest hotel: Pebbles Inn
# bethel - nearest hotel: Hampton Inn Danbury
# kaoma - nearest hotel: Pumulo Pardway Lodge
# ribeira grande - nearest hotel: Hospedaria JSF
# stanley - nearest hotel: Hotel 52
# san felipe - nearest hotel: No hotel found
# prince rupert - nearest hotel: Crest Hotel
# la ronge - nearest hotel: La Ronge Hotel and Suites
# bengkulu - nearest hotel: Dena Hotel
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# port mathurin - nearest hotel: Escale Vacances
# invercargill - nearest hotel: The Grand
# nuuk - nearest hotel: Nordbo
# san patricio - nearest hotel: No hotel found
# longyearbyen - nearest hotel: The Vault
# zaozersk - nearest hotel: Северное сияние
# tolanaro - nearest hotel: Hôtel Mahavokey
# crane - nearest hotel: No hotel found
# antofagasta - nearest hotel: Hotel Colón
# margaret river - nearest hotel: Margaret River Hotel
# pisco - nearest hotel: La Portada
# al jawf - nearest hotel: No hotel found
# bredasdorp - nearest hotel: Victoria Hotel
# kingston - nearest hotel: Aphrodite Hotel
# forster - nearest hotel: No hotel found
# shenjiamen - nearest hotel: Zhonghan Hotel
# revda - nearest hotel: Металлург
# klyuchi - nearest hotel: No hotel found
# lompoc - nearest hotel: Red Roof Inn Lompoc
# sajir - nearest hotel: No hotel found
# st. john's - nearest hotel: Alt Hotel
# badger - nearest hotel: Clarion Hotel & Suites
# vilyuysk - nearest hotel: Мария
# illapel - nearest hotel: Domingo Ortiz de Rosas
# lagoa - nearest hotel: Casa da Madrinha
# smara - nearest hotel: Hôtel Amine فندق الأمين
# chibougamau - nearest hotel: No hotel found
# okahandja - nearest hotel: Okahandja Country Hotel
# saint-joseph - nearest hotel: PALM Hotel & Spa
# sovetskiy - nearest hotel: Кировская
# afaahiti - nearest hotel: Omati Lodge
# acarau - nearest hotel: No hotel found
# whitehorse - nearest hotel: Town & Mountain Hotel
# mammoth lakes - nearest hotel: Travelodge by Wyndham Mammoth Lakes
# puerto baquerizo moreno - nearest hotel: Dory's House
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# cherrapunji - nearest hotel: Rani Homestay
# cidreira - nearest hotel: Hotel Castelo
# flying fish cove - nearest hotel: Christmas Island Lodge
# albany - nearest hotel: No hotel found
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# praia da vitoria - nearest hotel: Salles
# nelson bay - nearest hotel: No hotel found
# qaqortoq - nearest hotel: Hotel Qaqortoq
# vila velha - nearest hotel: Hotel Prainha
# ribas do rio pardo - nearest hotel: Hotel São Francisco
# tazovsky - nearest hotel: Тазовчанка
# mahdia - nearest hotel: La Maison Bleue
# bilibino - nearest hotel: No hotel found
# les cayes - nearest hotel: No hotel found
# camana - nearest hotel: Caja Arequipa
# port lincoln - nearest hotel: Boston Hotel
# ixtapa - nearest hotel: Ma. Cristina
# walvis bay - nearest hotel: Atlantic
# hermanus - nearest hotel: Aloe guest house
# hawaiian paradise park - nearest hotel: No hotel found
# preobrazheniye - nearest hotel: No hotel found
# dixon - nearest hotel: Best Western Plus Dixon Davis
# ar rudayyif - nearest hotel: No hotel found
# bambous - nearest hotel: Anelia Villas & Spa
# kalajoki - nearest hotel: Hotel Rantakalla
# debark' - nearest hotel: Great Work Cafe and Pension
# mhamid - nearest hotel: Hotel Kasbah Azalay
# bayanaul - nearest hotel: Жан
# maragogi - nearest hotel: Pousada Mariluz
# moose jaw - nearest hotel: Temple Gardens Mineral Spa Resort
# dongola - nearest hotel: Lord
# fisterra - nearest hotel: Hotel Temático do Banco Azul
# at taj - nearest hotel: No hotel found
# nar'yan-mar - nearest hotel: Гостиница "Агат"
# enewetak - nearest hotel: No hotel found
# yaren - nearest hotel: Aiwo Hotel
# nova sintra - nearest hotel: Residência Ka Dencho
# west island - nearest hotel: Cocos Village Bungalows
# salinopolis - nearest hotel: Hotel Salinópolis
# pimentel - nearest hotel: Hospedaje Calle del Sol
# mitsamiouli - nearest hotel: Hotel le Paradis
# weno - nearest hotel: High Tide Hotel
# tarauaca - nearest hotel: Hotel Estrela
# mkushi - nearest hotel: Shalom Lodge
# sisimiut - nearest hotel: Sømandshjemmet
# bargaal - nearest hotel: Makka Hotel Bargaal
# vorkuta - nearest hotel: "Мегаполис"
# amga - nearest hotel: "АммА"
# javanrud - nearest hotel: No hotel found
# bocana de paiwas - nearest hotel: No hotel found
# toliara - nearest hotel: Ambary
# rufino - nearest hotel: Hotel Quime Quipán
# kajuru - nearest hotel: No hotel found
# campos belos - nearest hotel: No hotel found
# bojnurd - nearest hotel: مرکز آموزشی رفاهی فرهنگیان بجنورد
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# lakota - nearest hotel: Hôtel Gnoupalé
# boca suno - nearest hotel: No hotel found
# katsuren-haebaru - nearest hotel: No hotel found
# susuman - nearest hotel: No hotel found
# anadyr - nearest hotel: Гостевой дом
# castillos - nearest hotel: A mi gente
# mishkino - nearest hotel: Сова
# baruun-urt - nearest hotel: No hotel found
# callao - nearest hotel: Casa Ronald
# colonia - nearest hotel: Wasserturm Hotel Cologne
# mersing - nearest hotel: Mersing Inn Hotel
# atafu village - nearest hotel: No hotel found
# san rafael del sur - nearest hotel: Barceló Montelimar
# uliastay - nearest hotel: Болоржин зочид буудал
# gadzhiyevo - nearest hotel: Оазис
# magomeni - nearest hotel: La Vista Inn
# ta`u - nearest hotel: No hotel found
# cromer - nearest hotel: Hotel de Paris
# san antonio de pale - nearest hotel: No hotel found
# severo-yeniseyskiy - nearest hotel: Актолик
# mata-utu - nearest hotel: Gîte Oceania
# ussel - nearest hotel: Le Terminus
# chaohu - nearest hotel: No hotel found
# fort st. john - nearest hotel: Fort St. John Motor Inn
# quellon - nearest hotel: Aliwen
# gazipasa - nearest hotel: Güven Otel
# vernon - nearest hotel: Okanagan Royal Park Inn
# tabas - nearest hotel: هتل امیر
# saint-pierre - nearest hotel: Tropic Hotel
# griffith - nearest hotel: Quality Inn & Suites Hammond
# westport - nearest hotel: Norwalk Inn and Conference Center
# aasiaat - nearest hotel: SØMA
# port douglas - nearest hotel: Mantra Aqueous Port Douglas
# el burgo de osma - nearest hotel: Hotel Termal Burgo de Osma
# ola - nearest hotel: No hotel found
# zapala - nearest hotel: Apart Solar de Piedra
# arno - nearest hotel: Pensionat Grisslehamns
# darwin - nearest hotel: Mantra Pantanas Darwin
# ridder - nearest hotel: Алтай
# nema - nearest hotel: No hotel found
# boguchany - nearest hotel: Полет
# hualien city - nearest hotel: view hoster
# kodiak - nearest hotel: No hotel found
# port elizabeth - nearest hotel: Waterford Hotel
# vanino - nearest hotel: Пять Звёзд
# navolato - nearest hotel: Hotel Maioris Navolato
# sananduva - nearest hotel: No hotel found
# vozhega - nearest hotel: No hotel found
# reggane - nearest hotel: No hotel found
# bernay - nearest hotel: Logis d'Aline
# amahai - nearest hotel: Hotel Irene
# takhatgarh - nearest hotel: No hotel found
# lhasa - nearest hotel: Shangri-la Hotel Lhasa
# tibati - nearest hotel: Hôtel Calypso Annexe
# eyl - nearest hotel: فندق ايل دابي
# richards bay - nearest hotel: SUN1 Richards Bay
# halabjah - nearest hotel: موتيل سازان
# west bay - nearest hotel: Bonnie's Arch
# iron river - nearest hotel: AmericInn
# necocli - nearest hotel: Casa Hotel Necoclí
# mossendjo - nearest hotel: Louesse Palace
# selkirk - nearest hotel: No hotel found
# guymon - nearest hotel: Comfort Inn & Suites
# labuan - nearest hotel: Labuan Avenue Hotel
# porto novo - nearest hotel: Hôtel 6500 CFA
# rotonda west - nearest hotel: Sea Oats Beach Club
# cockburn town - nearest hotel: The Salt Raker Inn
# gotse delchev - nearest hotel: No hotel found
# fayroz koh - nearest hotel: No hotel found
# nampula - nearest hotel: Hotel Lurio
# senekal - nearest hotel: No hotel found
# kirensk - nearest hotel: Ивушка
# galle - nearest hotel: Jungle Hostel Villa
# greymouth - nearest hotel: Recreation Hotel
# palasa - nearest hotel: No hotel found
# chernyshevskiy - nearest hotel: No hotel found
# rio grande - nearest hotel: Hotel Vila Moura Executivo
# angaur state - nearest hotel: No hotel found
# tamandare - nearest hotel: Pousada Baia dos Corais
# bahia de caraquez - nearest hotel: No hotel found
# weston - nearest hotel: TownePlace Suites by Marriott Fort Lauderdale Weston
# seaside - nearest hotel: Embassy Suites
# yelizovo - nearest hotel: Николина Усадьба
# philadelphia - nearest hotel: The Ritz-Carlton, Philadelphia
# burgersdorp - nearest hotel: No hotel found
# butte - nearest hotel: No hotel found
# minas de marcona - nearest hotel: No hotel found
# temuco - nearest hotel: Hostal Rayen Centro
# moab - nearest hotel: Kokopelli Inn
# sindangan - nearest hotel: Green Palace
# kencong - nearest hotel: Grand Gumuk Mas Hotel
# kuruman - nearest hotel: Palermo Inn
# nizhnesortymskiy - nearest hotel: Нижнесортымский
# nemuro - nearest hotel: お宿エクハシ
# tual - nearest hotel: Suita
# dauphin - nearest hotel: No hotel found
# slave lake - nearest hotel: Northwest Inn
# la paz - nearest hotel: Alojamiento Tokio
# guerrero negro - nearest hotel: Plaza sal paraiso
# baoqing - nearest hotel: No hotel found
# kalmunai - nearest hotel: Saji new food
# port moresby - nearest hotel: The Sanctuary Hotel and Spa
# margate - nearest hotel: The Reading Rooms
# urucara - nearest hotel: No hotel found
# swakopmund - nearest hotel: Amanpuri Travellers Lodge
# port blair - nearest hotel: Andaman Ocean Breeze
# el granada - nearest hotel: Beach House
# remire-montjoly - nearest hotel: Complexe Belova
# dubna - nearest hotel: Дубна, корпус 3
# palu - nearest hotel: Ujung Pandang Hotel
# kailua-kona - nearest hotel: Kona Seaside Hotel
# fada - nearest hotel: No hotel found
# talnakh - nearest hotel: Талнах
# akureyri - nearest hotel: Hótel Norðurland
# kone - nearest hotel: Pacifik Appartels
# mar del plata - nearest hotel: Gran hotel Mónaco
# yuzhno-kurilsk - nearest hotel: Айсберг
# jamestown - nearest hotel: DoubleTree Jamestown
# new norfolk - nearest hotel: Woodbridge on the Derwent
# egra - nearest hotel: Hotel Hvězda
# penn yan - nearest hotel: Microtel by Wyndham Penn Yan Finger Lakes Region
# sitka - nearest hotel: Aspen Suites Hotel
# fabens - nearest hotel: No hotel found
# santana - nearest hotel: Hotel Teodoro
# badiyah - nearest hotel: Al Areen Hotel Apartments
# iquique - nearest hotel: Hostal Vivar
# inhambane - nearest hotel: Hotel de Inhambane
# saint-philippe - nearest hotel: Le Baril
# tralee - nearest hotel: The Ashe Hotel
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# zhaobaoshan - nearest hotel: 新天地宾馆
# pampa - nearest hotel: AmericInn
# guozhen - nearest hotel: No hotel found
# dakhla - nearest hotel: Hotel El Massira
# ghat - nearest hotel: فندق تاسيلي
# geraldton - nearest hotel: Ocean Centre Hotel
# tindouf - nearest hotel: محمد بوسبي
# extrema - nearest hotel: Hotel San Marco
# quelimane - nearest hotel: Mabassa
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# tromso - nearest hotel: Clarion Collection Hotel Aurora
# phek - nearest hotel: No hotel found
# tinyahuarco - nearest hotel: RJ
# kapa'a - nearest hotel: Pono Kai Resort
# burley - nearest hotel: Hampton Inn & Suites
# show low - nearest hotel: Quality Inn
# lata - nearest hotel: Residencial Botânico
# surendranagar - nearest hotel: No hotel found
# tevriz - nearest hotel: No hotel found
# khandyga - nearest hotel: Апельсин
# kristiansund - nearest hotel: Comfort Hotel Fosna
# saint-francois - nearest hotel: Chez Lily
# savonlinna - nearest hotel: Kylpylähotelli Kasino
# mount isa - nearest hotel: Ibis Styles
# vilyuchinsk - nearest hotel: Победа
# harper - nearest hotel: No hotel found
# guarapari - nearest hotel: Osmar Hotel
# san ignacio rio muerto - nearest hotel: No hotel found
# viqueque - nearest hotel: Hotel Wailakurini
# cahul - nearest hotel: Azalia
# sokolka - nearest hotel: No hotel found
# lovisa - nearest hotel: Hotelli Uninen
# hailar - nearest hotel: 呼伦贝尔融府商务酒店
# igarka - nearest hotel: Заполярье
# torbat-e jam - nearest hotel: No hotel found
# machina - nearest hotel: No hotel found
# meadow lakes - nearest hotel: Best Western Lake Lucille Inn
# mont-laurier - nearest hotel: Confort Inn
# udachny - nearest hotel: Вилюй
# anchorage - nearest hotel: Hotel Captain Cook
# guadalupe y calvo - nearest hotel: No hotel found
# glendive - nearest hotel: La Quinta Inn & Suites by Wyndham Glendive
# coquimbo - nearest hotel: Hotel Iberia
# mili - nearest hotel: No hotel found
# kwang binh - nearest hotel: Nhà hàng Amor Palace
# fuxin - nearest hotel: 凯文国际商务酒店
# nova xavantina - nearest hotel: Hotel Morada do Sol
# wamba - nearest hotel: No hotel found
# murzuq - nearest hotel: فندق باريس - مرزق
# skovorodino - nearest hotel: Стелла
# puerto aysen - nearest hotel: Hostal Dendal
# manadhoo - nearest hotel: Soneva Jani
# mandan - nearest hotel: North Country Inn
# banda aceh - nearest hotel: Hotel 61
# egilsstadir - nearest hotel: Valaskjálf
# neelankarai - nearest hotel: Hotel Park Plaza Chennai OMR
# zhezqazghan - nearest hotel: No hotel found
# mount pleasant - nearest hotel: Old Village Post House
# pagar alam - nearest hotel: Villa Dempo Flower
# al kharijah - nearest hotel: Kharga Hotel
# kharp - nearest hotel: Собь
# namibe - nearest hotel: Nelsal Pensao
# chissamba - nearest hotel: No hotel found
# kununurra - nearest hotel: No hotel found
# bima - nearest hotel: No hotel found
# whitby - nearest hotel: Resolution Hotel
# jindabyne - nearest hotel: Lake Jindabyne Hotel
# filadelfia - nearest hotel: The Ritz-Carlton, Philadelphia
# naze - nearest hotel: ビジネス旅館畠山
# okhotsk - nearest hotel: No hotel found
# touros - nearest hotel: Pousada Atlântico
# caleta de carquin - nearest hotel: Hotel Mi Choacan
# coihueco - nearest hotel: No hotel found
# kutum - nearest hotel: No hotel found
# dogonbadan - nearest hotel: هتل پاسارگاد
# batikent - nearest hotel: Ostimpark Business Hotel
# chegdomyn - nearest hotel: Бурея
# galeana - nearest hotel: Hotel Jardin
# tessaoua - nearest hotel: No hotel found
# eastham - nearest hotel: Four Points by Sheraton
# shanwei - nearest hotel: 汕尾保利希尔顿逸林酒店
# cambria - nearest hotel: Olallieberry Inn
# phan thiet - nearest hotel: Khách sạn Cà Ty
# psebay - nearest hotel: Псебай
# mount pearl - nearest hotel: Sandman Signature St. John's Hotel
# tucuma - nearest hotel: No hotel found
# masterton - nearest hotel: Copthorne Hotel Solway Park
# jumla - nearest hotel: Amar Sandesh Guesthouse
# ternopil - nearest hotel: Авалон Палац
# tari - nearest hotel: No hotel found
# brookings - nearest hotel: Quality Inn
# san martin - nearest hotel: Hotel Lacava
# zholymbet - nearest hotel: No hotel found
# narrabri - nearest hotel: Tattersall's Hotel
# puerto rico - nearest hotel: Suizo
# salmon arm - nearest hotel: SureStay Plus Hotel by Best Western Salmon Arm
# kavieng - nearest hotel: Kavieng Hotel
# chamba - nearest hotel: Lodge
# dapa - nearest hotel: Island Suites
# anapa - nearest hotel: Анапа Лазурная
# beau vallon - nearest hotel: Le Jardin de Beau Vallon
# lebu - nearest hotel: No hotel found
# greenville - nearest hotel: Quality Inn
# amlapura - nearest hotel: Hotel Ganitri Oka
# turaif - nearest hotel: المودة
# nouadhibou - nearest hotel: Hotel valencia
# mbekenyera - nearest hotel: No hotel found
# sa'dah - nearest hotel: الشارقة مول للمواد الغذائية
# ban talat bueng - nearest hotel: U-Dee
# opuwo - nearest hotel: Ohakane Lodge
# shimoda - nearest hotel: ホテルウラガ
# grand falls-windsor - nearest hotel: Hotel Robin Hood
# saint croix - nearest hotel: The Buccaneer
# kuta - nearest hotel: Ida Hotel Bali
# balsta - nearest hotel: Woodstock B&B
# shakhtinsk - nearest hotel: Гостинично-развлекательный комплекс «Табыс»
# kavaratti - nearest hotel: No hotel found
# mcalester - nearest hotel: Hiway Motor Inn & Suites
# ifrane - nearest hotel: la perle d'azrou
# guatrache - nearest hotel: No hotel found
# bontang - nearest hotel: Hotel Sederhana
# taroudant - nearest hotel: Hotel Tiouit
# usogorsk - nearest hotel: Единственная
# dzitbalche - nearest hotel: No hotel found
# libreville - nearest hotel: No hotel found
# turner - nearest hotel: No hotel found
# ojinaga - nearest hotel: Hotel
# oranjemund - nearest hotel: Op My Stoep
# fomboni - nearest hotel: Mohéli La Plage
# aykhal - nearest hotel: Уют
# barghat - nearest hotel: No hotel found
# thohoyandou - nearest hotel: Khoroni Hotel Casino and Convention Resort
# togur - nearest hotel: Визит
# guanica - nearest hotel: Copamarina Beach Resort
# al qitena - nearest hotel: No hotel found
# chimoio - nearest hotel: Hotel Amirana
# knyaze-volkonskoye - nearest hotel: No hotel found
# samana - nearest hotel: Hotel Cotubanamá
# itapirapua - nearest hotel: No hotel found
# el jadid - nearest hotel: Hotel El Jadida فندق الجديدة
# puerto deseado - nearest hotel: Los Olmos
# betio village - nearest hotel: Seaman Hostel
# montevideo - nearest hotel: Hotel Escuela
# port hedland - nearest hotel: The Esplanade Hotel
# laguna - nearest hotel: Holiday Inn Express & Suites
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# codrington - nearest hotel: No hotel found
# thief river falls - nearest hotel: Quality Inn
# sinabang - nearest hotel: No hotel found
# tobelo - nearest hotel: JJ Guesthouse
# vorgashor - nearest hotel: София
# kolokani - nearest hotel: Hôtel kolokani
# sheringham - nearest hotel: The Two Lifeboats Hotel
# inarajan village - nearest hotel: No hotel found
# ende - nearest hotel: LCR Hotel
# zvishavane - nearest hotel: Zvishavane Panorama Lodge
# celestun - nearest hotel: Hotel Flamingo Playa
# mandalgovi - nearest hotel: Б
# marquette - nearest hotel: No hotel found
# mogocha - nearest hotel: 7Ka
# xilin hot - nearest hotel: Hotel hailibu 120
# cabedelo - nearest hotel: No hotel found
# qamdo - nearest hotel: 银杏商务宾馆
# chos malal - nearest hotel: Hospedaje Lemus
# charlottetown - nearest hotel: Holman Grand Hotel
# arraial do cabo - nearest hotel: No hotel found
# kurkino - nearest hotel: No hotel found
# fort bragg - nearest hotel: Airborne Inn Lodging
# buala - nearest hotel: No hotel found
# holualoa - nearest hotel: Kona Hotel
# motueka - nearest hotel: Hotel Motueka
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# hami - nearest hotel: Хами
# antonio enes - nearest hotel: Hotel Quirimbas
# shache - nearest hotel: 莎車新盛賓舘
# itacare - nearest hotel: Pousada Raisis
# musan-up - nearest hotel: No hotel found
# horta - nearest hotel: Azoris Faial Garden - Resort Hotel
# hermantown - nearest hotel: Holiday Inn Express & Suites Duluth North - Miller Hill
# basni - nearest hotel: Ranvas Nagaur
# pacasmayo - nearest hotel: Playa Linda
# prado - nearest hotel: Pousada Recanto do Prado
# vadso - nearest hotel: Scandic Vadsø
# kharkhorin - nearest hotel: 점심식사 good restaurant.
# priozersk - nearest hotel: Корела
# cruzeiro do sul - nearest hotel: Estrela Palace Hotel
# midvagur - nearest hotel: GiljaHome
# mateus leme - nearest hotel: Hotel Fazenda Boa Esperança
# pangody - nearest hotel: Газпром энерго
# talovskiy - nearest hotel: Аура
# cabo san lucas - nearest hotel: Comfort Rooms
# iskateley - nearest hotel: Авантаж
# polyarnyy - nearest hotel: No hotel found
# howrah - nearest hotel: Sun India Guest House
# camacupa - nearest hotel: No hotel found
# mabaruma - nearest hotel: Monty Brooms Hotel
# hermosillo - nearest hotel: Lucerna
# flin flon - nearest hotel: Copperbelt Hotel
# magadi - nearest hotel: Udupi Upahara
# ghanzi - nearest hotel: Ghanzi farmhouse
# gdynia - nearest hotel: Willa Julia
# noosa heads - nearest hotel: Costa Nova Apartments
# wuwei - nearest hotel: Hepingli Boutique Hotel
# lincoln city - nearest hotel: Inn at Lincoln City
# tura - nearest hotel: Hotel Polo Orchid
# bodo - nearest hotel: Zefyr hotell
# awjilah - nearest hotel: No hotel found
# palikir - national government center - nearest hotel: Mangrove Bay Hotel
# utrik - nearest hotel: No hotel found
# swan hill - nearest hotel: Murray Downs Golf Resort
# pomorie - nearest hotel: REGATA
# ribeira brava - nearest hotel: Cheerfulway Bravamar Hotel
# bilbays - nearest hotel: No hotel found
# coeur d'alene - nearest hotel: Roosevelt Inn
# las khorey - nearest hotel: No hotel found
# tymovskoye - nearest hotel: No hotel found
# dhidhdhoo - nearest hotel: Cinnamon Island
# queenstown - nearest hotel: Queens Hotel
# kupang - nearest hotel: HOTEL SALUNGA
# kerikeri - nearest hotel: Avalon Resort
# letlhakeng - nearest hotel: No hotel found
# coahuayana de hidalgo - nearest hotel: No hotel found
# pointe-noire - nearest hotel: HÔTEL F.A.R.E
# ilaro - nearest hotel: No hotel found
# kolwezi - nearest hotel: Guest House le Manguier
# verkhniye sergi - nearest hotel: No hotel found
# brandon - nearest hotel: Brandon Motor Lodge
# alesund - nearest hotel: Brosundet
# hammerfest - nearest hotel: Thon Hotel Hammerfest
# ringkobing - nearest hotel: Town Living
# taltal - nearest hotel: Hostería Taltal
# kapuskasing - nearest hotel: Travelodge
# idri - nearest hotel: No hotel found
# prince albert - nearest hotel: No hotel found
# nadi - nearest hotel: President Hotel
# santa luzia - nearest hotel: Alcoboca
# north bay - nearest hotel: Days Inn
# jisr ash shughur - nearest hotel: No hotel found
# crucecita - nearest hotel: No hotel found
# tashtyp - nearest hotel: No hotel found
# patterson - nearest hotel: Hampton Inn & Suites
# hohhot - nearest hotel: Yue Jia Budget Hotel (foreigners approved)
# coruripe - nearest hotel: No hotel found
# kumagunnam - nearest hotel: No hotel found
# ladovskaya balka - nearest hotel: No hotel found
# montreal-ouest - nearest hotel: Ramada Plaza by Wyndham
# kimbe - nearest hotel: Kimbe Bay Hotel
# bamboo flat - nearest hotel: Hotel Megapode Nest
# padang - nearest hotel: losmen Surya
# borskoye - nearest hotel: Элегия
# rio branco - nearest hotel: No hotel found
# n'zeto - nearest hotel: No hotel found
# khairagarh - nearest hotel: No hotel found
# tibanbang - nearest hotel: No hotel found
# zhangjiakou shi xuanhua qu - nearest hotel: Century dynasty hotel
# nishinoomote - nearest hotel: ゼウスハウス
# diofior - nearest hotel: Souimanga Lodge
# abqaiq - nearest hotel: No hotel found
# zharkent - nearest hotel: Hotel (good)
# murghob - nearest hotel: Pamir Hotel
# az zulfi - nearest hotel: Alfaleh
# calca - nearest hotel: House Hotel
# egersund - nearest hotel: Grand hotell Egersund
# tomatlan - nearest hotel: Hotel Hacienda Vieja Tomatlan
# kewanee - nearest hotel: Kewanee Motor Lodge
# faya-largeau - nearest hotel: No hotel found
# itabera - nearest hotel: No hotel found
#              City Country      Lat       Lng  Humidity  \
# 0       okakarara     NaN -20.5833   17.4333        35
# 1       adamstown      PN -25.0660 -130.1015        78
# 2           lihue      US  21.9789 -159.3672        69
# 3        sai buri      TH   6.7013  101.6168        79
# 4    punta arenas      CL -53.1500  -70.9167        87
# ..            ...     ...      ...       ...       ...
# 574      egersund      NO  58.4513    5.9997        87
# 575      tomatlan      MX  19.9333 -105.2500        35
# 576       kewanee      US  41.2456  -89.9248        54
# 577  faya-largeau      TD  17.9257   19.1043        13
# 578       itabera      BR -23.8619  -49.1372        50
#
#                         Hotel name
# 0                   No hotel found
# 1                   No hotel found
# 2                      Kauai Palms
# 3               موقع .٢ مشروع فندق
# 4                    Hotel Lacolet
# ..                             ...
# 574          Grand hotell Egersund
# 575  Hotel Hacienda Vieja Tomatlan
# 576            Kewanee Motor Lodge
# 577                 No hotel found
# 578                 No hotel found
#
# [579 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
#Create hover text with city, hotel name, and country information
# Plot the cities with hover information
plot = hotel_df.hvplot.points('Lng', 'Lat', geo=True, tiles='OSM', size=10, hover_cols=['City', 'Hotel name', 'Country'], title='Map Plot Example')

# Display the map
plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel name,Country)
